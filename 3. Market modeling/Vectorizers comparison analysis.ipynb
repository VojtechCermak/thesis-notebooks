# %%
import pandas as pd

# %%
emb = pd.read_csv('emb_results.csv', header=[0, 1], skipinitialspace=True, index_col=0)
tf = pd.read_csv('tf_results.csv', header=[0, 1], skipinitialspace=True, index_col=0)

# %%
emb.T[['CV 20 MSE', 'CV 8 MSE', 'CV 3 MSE']]
# Out:
#                           CV 20 MSE      CV 8 MSE      CV 3 MSE
# Apple  idf             3.350000e-07  3.360000e-07  3.410000e-07
#        idf_sw          3.320000e-07  3.320000e-07  3.380000e-07
#        mean            3.380000e-07  3.390000e-07  3.400000e-07
#        mean_sw         3.370000e-07  3.390000e-07  3.400000e-07
#        minmax          5.220000e-07  5.150000e-07  4.920000e-07
#        glove_200       3.340000e-07  3.340000e-07  3.360000e-07
#        glove_25        3.350000e-07  3.360000e-07  3.400000e-07
#        glove_300_wiki  3.430000e-07  3.450000e-07  3.460000e-07
#        w2v_200         3.550000e-07  3.560000e-07  3.640000e-07
#        full            3.360000e-07  3.360000e-07  3.380000e-07
#        lemmas          3.360000e-07  3.350000e-07  3.410000e-07
#        stems           3.390000e-07  3.400000e-07  3.440000e-07
# Google idf             1.400000e-07  1.390000e-07  1.400000e-07
#        idf_sw          1.410000e-07  1.410000e-07  1.410000e-07
# ...
